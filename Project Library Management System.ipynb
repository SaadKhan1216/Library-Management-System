# %%
from datetime import datetime
def clear():
    from IPython.display import clear_output
    clear_output()
    return clear
def islamic():
    ifile=open('islamic.txt','r')
    print('These books are available on Islamic topics at the moment:\n')
    for b in ifile:
        b = b.split(',')
        if b[2][-1:]=='\n':
            print('{:<10s}'.format(b[2][:-1]))
        else:
            print('{:<10s}'.format(b[2]))
    ifile.close()
    return islamic
def novel():
    ifile=open('novel.txt','r')
    print('These novels are available:\n')
    for b in ifile:
        b=b.split(',')
        if b[2][-1:]=='\n':
            print('{:<10s}'.format(b[2][:-1]))
        else:
            print('{:<10s}'.format(b[2]))
    ifile.close()
    return novel
def history():
    ifile=open('history.txt','r')
    print('These books area available on history topics at the moment:\n')
    for b in ifile:
        b=b.split(',')
        if b[2][-1:]=='\n':
            print('{:<10s}'.format(b[2][:-1]))
        else:
            print('{:<10s}'.format(b[2][:-1]))
    ifile.close()
    return history
def course():                   
    ifile=open('course.txt','r')
    print('These course books are available at the moment:\n')
    for b in ifile:
        b=b.split(',')
        if b[2][-1:]=='\n':
            print('{:<10s}'.format(b[2][:-1]))
        else:
            print('{:<10s}'.format(b[2][:-1]))
    ifile.close()
    return course

print('\t\t\t\t\t\t Welcome To Library')
a=1
while a==1:
    print('What you want to check \n 1.Collection \n 2.Book Issue \n 3.Update Books \n 4.Exit')
    choice=eval(input('Enter What you want to check:\n'))
    clear()
    if choice==1:
        p=1
        while p==1:
            print('Choose option: \n 1.Islamic \n 2.Novels \n 3.History \n 4.Course Books \n 5.Mainmenu')
            choose=eval(input('Enter What type of Book? : '))
            clear()
            if choose==1:
                islamic()
                p=eval(input('Press 1 to return to Book types menu 0 to mainmenu: '))
                clear()
            elif choose==2:
                novel()
                p=eval(input('Press 1 to return to Book types menu 0 to mainmenu: '))
                clear()
            elif choose==3:
                history()
                p=eval(input('Press 1 to return to Book types menu 0 to mainmenu: '))
                clear()
            elif choose==4:
                course()
                p=eval(input('Press 1 to return to Book types menu 0 to mainmenu: '))
                clear()
            elif choose==5:
                p=0
                clear()
    elif choice==2:
        p=1
        while p==1:
            print('Which type of  book you want to issue? \n 1.Islamic \n 2.Novels \n 3.History \n 4.Course Books \n 5.Mainmenu')
            choose=eval(input('What type do you want? \n'))
            clear()
            if choose==1:
                print('Do you want to check the collection of Islamic Books (yes or no)')
                Choose=str(input('yes or no? \n'))
                clear()
                if Choose=='yes':
                    islamic()
                book=input('Enter the name of book you want:\n')
                name = input('Enter your name: ')
                f = open('islamic.txt','r')
                x = f.readlines()
                f.close()
                for i in x:
                    ind = x.index(i)
                    k = datetime.now().strftime('%d/%m/%y')
                    i = i.split(',')
                    if book == i[2][:-1] and i[-1]!= 'i\n':
                        print('You have issued this book on',k)
                        x[ind]=i[0]+','+i[1]+','+book+','+name+','+k+','+'i\n'
                        f = open('islamic.txt','w')
                        f.writelines(x)
                        f.close()
                        break
                    elif book == i[2] and i[-1]== 'i\n':
                        print('This book has already been issued and not available at the moment!')
                        break
                else:
                    print('This book is not available.')
                p=eval(input('Press 1 to return to Book Issue menu 0 to mainmenu: '))
                clear()
            elif choose==2:
                print('Do you want to check the collection of Novels (yes or no)')
                Choose=str(input('yes or no? \n'))
                clear()
                if Choose=='yes':
                    novel()
                book=input('Enter the name of book you want:\n')
                name = input('Enter your name: ')
                f = open('novel.txt','r')
                x = f.readlines()
                f.close()
                for i in x:
                    ind = x.index(i)
                    k = datetime.now().strftime('%d/%m/%y')
                    i = i.split(',')
                    if book == i[2][:-1] and i[-1]!= 'i\n':
                        print('You have issued this book on',k)
                        x[ind]=i[0]+','+i[1]+','+book+','+name+','+k+','+'i\n'
                        f = open('novel.txt','w')
                        f.writelines(x)
                        f.close()
                        break
                    elif book == i[2] and i[-1]== 'i\n':
                        print('This book has already been issued and not available at the moment!')
                        break
                else:
                    print('This book is not available.')
                p=eval(input('Press 1 to return to Book Issue menu 0 to mainmenu: '))
                clear()
            elif choose==3:
                print('Do you want to check the collection of History Books (yes or no)')
                Choose=str(input('yes or no? \n'))
                clear()
                if Choose=='yes':
                    history()
                book=input('Enter the name of book you want:\n')
                name = input('Enter your name: ')
                f = open('history.txt','r')
                x = f.readlines()
                f.close()
                for i in x:
                    ind = x.index(i)
                    k = datetime.now().strftime('%d/%m/%y')
                    i = i.split(',')
                    if book == i[2][:-1] and i[-1]!= 'i\n':
                        print('You have issued this book on',k)
                        x[ind]=i[0]+','+i[1]+','+book+','+name+','+k+','+'i\n'
                        f = open('history.txt','w')
                        f.writelines(x)
                        f.close()
                        break
                    elif book == i[2] and i[-1]== 'i\n':
                        print('This book has already been issued and not available at the moment!')
                        break
                else:
                    print('This book is not available.')
                p=eval(input('Press 1 to return to Book Issue menu 0 to mainmenu: '))
                clear()
            elif choose==4:
                print('Do you want to check the collection of Course Books (yes or no)')
                Choose=str(input('yes or no? \n'))
                clear()
                if Choose=='yes':
                    course()
                book=input('Enter the name of book you want:\n')
                name = input('Enter your name: ')
                f = open('course.txt','r')
                x = f.readlines()
                f.close()
                for i in x:
                    ind = x.index(i)
                    k = datetime.now().strftime('%d/%m/%y')
                    i = i.split(',')
                    if book == i[2][:-1] and i[-1]!= 'i\n':
                        print('You have issued this book on',k)
                        x[ind]=i[0]+','+i[1]+','+book+','+name+','+k+','+'i\n'
                        f = open('course.txt','w')
                        f.writelines(x)
                        f.close()
                        break
                    elif book == i[2] and i[-1]== 'i\n':
                        print('This book has already been issued and not available at the moment!')
                        break
                else:
                    print('This book is not available.')
                p=eval(input('Press 1 to return to Book Issue menu 0 to mainmenu: '))
                clear()
            elif choose==5:
                p=0
    elif choice==3:
        x=1
        while x==1:
            print('Which type do you want to update? \n 1.Islamic \n 2.Novels \n 3.History \n 4.Course Books \n 5.Mainmenu')
            choose=eval(input('Enter which you want to update: '))
            clear()
            if choose==1:
                infile=open('islamic.txt','a')
                q=str(input('Enter Book ISBN_N0: '))
                w=str(input('Enter Author Name: '))
                e=str(input('Enter Book Name: '))
                infile.write(q+','+w+','+e+'\n')
                infile.close()
                x=eval(input('Press 1 to return to Update Menu 0 to mainmenu: '))
                clear()
            elif choose==2:
                infile=open('novel.txt','a')
                q=str(input('Enter Book ISBN_N0: '))
                w=str(input('Enter Author Name: '))
                e=str(input('Enter Book Name: '))
                infile.write(q+','+w+','+e+'\n')
                infile.close()
                x=eval(input('Press 1 to return to Update Menu 0 to mainmenu: '))
                clear()
            elif choose==3:
                infile=open('history.txt','a')
                q=str(input('Enter Book ISBN_N0: '))
                w=str(input('Enter Author Name: '))
                e=str(input('Enter Book Name: '))
                infile.write(q+','+w+','+e+'\n')
                infile.close()
                x=eval(input('Press 1 to return to Update Menu 0 to mainmenu: '))
                clear()
            elif choose==4:
                infile=open('course.txt','a')
                q=str(input('Enter Book ISBN_N0: '))
                w=str(input('Enter Author Name: '))
                e=str(input('Enter Book Name: '))
                infile.write(q+','+w+','+e+'\n')
                infile.close()
                x=eval(input('Press 1 to return to Update Menu 0 to mainmenu: '))
                clear()
            elif choose==5:
                x=0
                clear()
    elif choice==4:
        print('\t\t\t\t Thankyou for coming to Library!')
        break
# Out:
# 				 Thankyou for coming to Library!
